# %% [markdown]
# <p style="text-align: center; font-size: 35px">به نام خدا</p>
# <p style="text-align: center; font-size: 25px">هوش مصنوعی</p>
# <p style="text-align: center; font-size: 25px">تمرین کامپیوتری شماره 4</p>
# <p style="text-align: center; font-size: 25px">علی مهرانی</p>
# <p style="text-align: center; font-size: 25px">شماره دانشجویی : 810198542</p>

# %%
import pandas as pd
import math

# %% [markdown]
# # Data analysis

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## q1

# %%
house_data = pd.read_csv('house_data.csv')
house_data.describe()
# Out:
#        Unnamed: 0.2  Unnamed: 0.1   Unnamed: 0            id         price  \
# count   21613.00000   21613.00000  21613.00000  2.161300e+04  2.161300e+04
# mean    10806.00000   10806.00000  10806.00000  4.580302e+09  5.401822e+05
# std      6239.28002    6239.28002   6239.28002  2.876566e+09  3.673622e+05
# min         0.00000       0.00000      0.00000  1.000102e+06  7.500000e+04
# 25%      5403.00000    5403.00000   5403.00000  2.123049e+09  3.219500e+05
# 50%     10806.00000   10806.00000  10806.00000  3.904930e+09  4.500000e+05
# 75%     16209.00000   16209.00000  16209.00000  7.308900e+09  6.450000e+05
# max     21612.00000   21612.00000  21612.00000  9.900000e+09  7.700000e+06
#
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count  21613.000000  21613.000000  18528.000000  2.161300e+04  18530.000000
# mean       3.367464      2.111900   2077.569031  1.510697e+04      1.492903
# ...

# %% [markdown]
# ## q2

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0.2   21613 non-null  int64
#  1   Unnamed: 0.1   21613 non-null  int64
#  2   Unnamed: 0     21613 non-null  int64
#  3   id             21613 non-null  int64
#  4   date           21613 non-null  object
#  5   price          21613 non-null  float64
#  6   bedrooms       21613 non-null  int64
#  7   bathrooms      21613 non-null  float64
#  8   sqft_living    18528 non-null  float64
#  9   sqft_lot       21613 non-null  int64
#  10  floors         18530 non-null  float64
#  11  waterfront     21613 non-null  int64
#  12  view           21613 non-null  int64
#  13  condition      21613 non-null  int64
#  14  grade          21613 non-null  int64
#  15  sqft_above     21613 non-null  int64
#  16  sqft_basement  21184 non-null  float64
# ...

# %%
house_data.isna().sum()
# Out:
# Unnamed: 0.2        0
# Unnamed: 0.1        0
# Unnamed: 0          0
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living      3085
# sqft_lot            0
# floors           3083
# waterfront          0
# view                0
# condition           0
# grade               0
# sqft_above          0
# sqft_basement     429
# yr_built         3082
# yr_renovated        0
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# location            0
# style               0
# house_age           0
# dtype: int64

# %% [markdown]
# It can be observed that columns 'sqft_living', 'floors', 'sqft_basement' and 'yr_built' have null values inside them.
# Right now we'll see percentage of null values in each column.
# Each column has total 21613 rows which in some of them there are null values.

# %%
for column in house_data:
    print(column, ':', house_data[column].isnull().sum() * 100 / len(house_data), "%")
# Out:
# Unnamed: 0.2 : 0.0 %
# Unnamed: 0.1 : 0.0 %
# Unnamed: 0 : 0.0 %
# id : 0.0 %
# date : 0.0 %
# price : 0.0 %
# bedrooms : 0.0 %
# bathrooms : 0.0 %
# sqft_living : 14.273816684402906 %
# sqft_lot : 0.0 %
# floors : 14.264562994494055 %
# waterfront : 0.0 %
# view : 0.0 %
# condition : 0.0 %
# grade : 0.0 %
# sqft_above : 0.0 %
# sqft_basement : 1.9849164854485726 %
# yr_built : 14.259936149539628 %
# yr_renovated : 0.0 %
# zipcode : 0.0 %
# lat : 0.0 %
# long : 0.0 %
# sqft_living15 : 0.0 %
# sqft_lot15 : 0.0 %
# location : 0.0 %
# style : 0.0 %
# house_age : 0.0 %

# %% [markdown]
# ## q3

# %%
correlation = house_data.corr().sort_values(by="price", ascending = False)
correlation
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_7896\1037540204.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = house_data.corr().sort_values(by="price", ascending = False)
#                Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        id     price  \
# price              0.027344      0.027344    0.027344 -0.016797  1.000000
# sqft_living        0.035777      0.035777    0.035777 -0.015295  0.676542
# sqft_above         0.071958      0.071958    0.071958 -0.010842  0.605566
# sqft_living15      0.026647      0.026647    0.026647 -0.002901  0.585374
# bathrooms          0.105578      0.105578    0.105578  0.005412  0.517952
# view              -0.013751     -0.013751   -0.013751  0.011592  0.397346
# grade              0.057077      0.057077    0.057077  0.006461  0.389227
# ...

# %%
corr_price = correlation.loc[:,"price"]

plt.figure(figsize=(30,5))
plt.plot(corr_price)
plt.legend(house_data.columns)

# %% [markdown]
# It can be observed that 'sqft_living', 'sqft_above' and 'sqft_living_15' have highest dependency to our goal column.

# %% [markdown]
# We can also plot the corellation matrix of our dataframe as an alternative approach.

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(house_data.corr(), fignum=f.number)
plt.xticks(range(house_data.select_dtypes(['number']).shape[1]), house_data.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(house_data.select_dtypes(['number']).shape[1]), house_data.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_7896\2196945496.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.matshow(house_data.corr(), fignum=f.number)

# %% [markdown]
# considering 'price' as our goal column, it can be observed that 'sqft_living', 'sqft_above' and 'sqft_living_15' have more correlation to our goal column.

# %% [markdown]
# ## q4

# %% [markdown]
# ### sqft_living

# %%
x_value_sqft_living = house_data['sqft_living'].unique()
x_value_sqft_living = x_value_sqft_living[~np.isnan(x_value_sqft_living)]
y_value_sqft_living = house_data['sqft_living'].value_counts()

plt.figure(figsize = (20, 8))
plt.subplot(2,3,1)
plt.scatter(x=x_value_sqft_living, y=y_value_sqft_living)
plt.subplot(2,3,2)
house_data['sqft_living'].hist()

plt.show()

# %% [markdown]
# ### sqft_above

# %%
x_value_sqft_above = house_data['sqft_above'].unique()
x_value_sqft_above = x_value_sqft_above[~np.isnan(x_value_sqft_above)]
y_value_sqft_above = house_data['sqft_above'].value_counts()

plt.figure(figsize = (20, 8))
plt.subplot(2,3,1)
plt.scatter(x=x_value_sqft_above, y=y_value_sqft_above)
plt.subplot(2,3,2)
house_data['sqft_above'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### sqft_living_15

# %%
x_value_sqft_living15 = house_data['sqft_living15'].unique()
x_value_sqft_living15 = x_value_sqft_living15[~np.isnan(x_value_sqft_living15)]
y_value_sqft_living15 = house_data['sqft_living15'].value_counts()

plt.figure(figsize = (20, 8))
plt.subplot(2,3,1)
plt.scatter(x=x_value_sqft_living15, y=y_value_sqft_living15)
plt.subplot(2,3,2)
house_data['sqft_living15'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## q5

# %% [markdown]
# ### sqft_living

# %%
plt.figure(figsize = (20, 8))

plt.subplot(2,3,1)
plt.scatter(x=house_data['sqft_living'], y=house_data['price'])
plt.subplot(2,3,2)
plt.hexbin(x=house_data['sqft_living'], y=house_data['price'], gridsize=50, bins='log')
plt.subplot(2,3,3)
plt.hexbin(x=[house_data['sqft_living']], y=house_data['price'], gridsize=50, bins='log')

house_data.plot.hexbin(x='sqft_living', y='price', gridsize=45)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python38\lib\site-packages\matplotlib\axes\_axes.py:4927: RuntimeWarning: invalid value encountered in cast
#   ix1 = np.round(ix).astype(int)
# c:\users\lenovo\appdata\local\programs\python\python38\lib\site-packages\matplotlib\axes\_axes.py:4929: RuntimeWarning: invalid value encountered in cast
#   ix2 = np.floor(ix).astype(int)
# <Axes: xlabel='sqft_living', ylabel='price'>

# %% [markdown]
# ### sqft_above

# %%
plt.figure(figsize = (20, 8))

plt.subplot(2,3,1)
plt.scatter(x=house_data['sqft_above'], y=house_data['price'])
plt.subplot(2,3,2)
plt.hexbin(x=house_data['sqft_above'], y=house_data['price'], gridsize=50, bins='log')
plt.subplot(2,3,3)
plt.hexbin(x=[house_data['sqft_above']], y=house_data['price'], gridsize=50, cmap='inferno')

house_data.plot.hexbin(x='sqft_above', y='price', gridsize=45)
# Out:
# <Axes: xlabel='sqft_above', ylabel='price'>

# %% [markdown]
# ### sqft_living15

# %%
plt.figure(figsize = (20, 8))

plt.subplot(2,3,1)
plt.scatter(x=house_data['sqft_living15'], y=house_data['price'])
plt.subplot(2,3,2)
plt.hexbin(x=house_data['sqft_living15'], y=house_data['price'], gridsize=50, bins='log')
plt.subplot(2,3,3)
plt.hexbin(x=[house_data['sqft_living15']], y=house_data['price'], gridsize=50, cmap='inferno')

house_data.plot.hexbin(x='sqft_living15', y='price', gridsize=45)
# Out:
# <Axes: xlabel='sqft_living15', ylabel='price'>

# %% [markdown]
# ## q6

# %% [markdown]
# Right now we will analyze missing values and their percentage in each field.
# We will also try differrent ways of handling  missing values in our dataset.

# %% [markdown]
# # Data preproccessing

# %% [markdown]
# ## q1

# %% [markdown]
# There are numerous ways of handling missing values in a dataset.
# Beside deleting columns or filling empty cells with aggregated values such as mean, mode or median, there are also other ways such as :
#
# 1- Dropping row or columns based on a threshold value:
# It might not be a good idea to delete all columns/rows containing nan values, it would be better to delete the ones that have 'lots of' missing values and to avoid those which have 'few' missing values, such method is done by dropping nan values based on a threshold value for example thresh=5 indicates that there must be at least 5 nan values in a row/column to be dropped.
#
# 2- Dropping based on a particular subset of columns:
# In this method, we select a subset of columns that if a row has nan values in those column, then that row will be marked for dropping.
#
# 3- Drop rows or columns that are full of missing values:
# Another situation is to have a column or row that is full of missing values. Such columns or rows are useless so we can drop them.
#
# 4- Constant value filling:
# We can select a constant value to replace all nan cells with it.
#
# 5- Replacing with the previous or next value:
# It is possible to replace the missing values in a column with the previous or next value in that column.
# This method might come in handy when working with time-series data.
#
# 6- Fill by using another data frame:
# We can also pass another data frame to the fillna function. The values in the new data frame will be used to replace the missing values in the current data frame.
#
# In this dataset, replacing missing values with mean for numerical data and replacement with mode for non-numerical, data would probably be the best option.

# %% [markdown]
# ## q2

# %% [markdown]
# In this section in order to fix the issue of missing values, we specify a threshold for percentage of missing values in each row/column.
# In rows/columns that the percentage of missing values is higher than the threshold value, that row/column will be deleted, else we'll replace empty cells of that row/column.
# We're actually trying to remove column/rows (data) that have a low amount of 'information gain.
# At last we try to remove rows that have negative value.

# %% [markdown]
# Columns 'sqft_living', 'floors', 'yr_built', 'sqft_basement' have highest number of missing values.

# %%
def get_percent_NaN(col_or_row) :
    return (col_or_row.isnull().sum() / len(col_or_row)) * 100

nan_col_percent = house_data.apply(get_percent_NaN)
nan_row_percent = house_data.apply(get_percent_NaN, axis=1)
# print(nan_col_percent)
# print(nan_row_percent)

# Remove cols and rows that have lots of NaN values according to threshold
limit_remove_col, limit_remove_row = 70, 30 #percentage
cols_should_remove = list(nan_col_percent[ nan_col_percent > limit_remove_col].index)
rows_should_remove = list(nan_row_percent[ nan_row_percent > limit_remove_row].index)

house_data.drop(cols_should_remove, axis="columns", inplace=True)
house_data.drop(rows_should_remove, axis="rows", inplace=True)

# fill NaN cell with mean of col
house_data.fillna(house_data.mean(), inplace = True)

# Remove rows that have negative value
# house_data = (house_data[(house_data[house_data.columns] >= 0).all(axis=1)])

house_data.info()
regr_data_ph1 = house_data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0.2   21613 non-null  int64
#  1   Unnamed: 0.1   21613 non-null  int64
#  2   Unnamed: 0     21613 non-null  int64
#  3   id             21613 non-null  int64
#  4   date           21613 non-null  object
#  5   price          21613 non-null  float64
#  6   bedrooms       21613 non-null  int64
#  7   bathrooms      21613 non-null  float64
#  8   sqft_living    21613 non-null  float64
#  9   sqft_lot       21613 non-null  int64
#  10  floors         21613 non-null  float64
#  11  waterfront     21613 non-null  int64
#  12  view           21613 non-null  int64
#  13  condition      21613 non-null  int64
#  14  grade          21613 non-null  int64
#  15  sqft_above     21613 non-null  int64
#  16  sqft_basement  21613 non-null  float64
# ...

# %% [markdown]
# ## q3

# %% [markdown]
# Standardization is a scaling technique in which the values end up being centered around the mean with a unit standard deviation.
# ![image.png](attachment:image.png)
#
# Normalization (a.k.a min-max scaling) is a scaling technique which tries to shift and rescale values so that they end up being in range of 0 to 1.
# ![image-2.png](attachment:image-2.png)
#
#
# Normalization is better to be used when we know that our data(values dataset) doesnt follow a gaussian distribution (a.k.a normal distribution).
# Standardization can be used when we know that our data follows a normal distribution.
# Now let us make a decision by analyzing our dataset.

# %%
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
house_data.hist(ax = ax)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_7896\2866479667.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   house_data.hist(ax = ax)
# array([[<Axes: title={'center': 'Unnamed: 0.2'}>,
#         <Axes: title={'center': 'Unnamed: 0.1'}>,
#         <Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'price'}>],
#        [<Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>,
#         <Axes: title={'center': 'sqft_living'}>,
#         <Axes: title={'center': 'sqft_lot'}>,
#         <Axes: title={'center': 'floors'}>],
#        [<Axes: title={'center': 'waterfront'}>,
#         <Axes: title={'center': 'view'}>,
#         <Axes: title={'center': 'condition'}>,
#         <Axes: title={'center': 'grade'}>,
#         <Axes: title={'center': 'sqft_above'}>],
#        [<Axes: title={'center': 'sqft_basement'}>,
# ...

# %% [markdown]
# It can be observed that some of our features(columns) are close to a normal dustribution.
# Also we would like our values to be in a more specific range in order to have a good measurement for comparing data, so we choose standardization technique here so that our values reach a normal distribution and most of values get in range of (-1,1).

# %%
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from pandas.api.types import is_numeric_dtype

for feature in house_data:
    if is_numeric_dtype(house_data[feature]) and feature != 'price':
        scaled_val = StandardScaler().fit(house_data[[feature]])
        house_data[feature] = scaled_val.transform(house_data[[feature]])

# %% [markdown]
# After standardization we can now see that mean of numeric column is now close to 0 and the standard deviation close to 1.

# %%
for feature in house_data:
    if is_numeric_dtype(house_data[feature]):
        print(feature, '=> mean:', house_data[feature].mean(), 'std:', house_data[feature].std())
# Out:
# Unnamed: 0.2 => mean: 0.0 std: 1.0000231350275917
# Unnamed: 0.1 => mean: 0.0 std: 1.0000231350275917
# Unnamed: 0 => mean: 0.0 std: 1.0000231350275917
# id => mean: 1.1440747330056672e-16 std: 1.0000231350275917
# price => mean: 540182.1587933188 std: 367362.2317180084
# bedrooms => mean: 2.4065020245981275e-16 std: 1.0000231350275917
# bathrooms => mean: 2.2092477602868056e-16 std: 1.0000231350275917
# sqft_living => mean: -3.156068228981151e-16 std: 1.0000231350275917
# sqft_lot => mean: 1.0520227429937171e-17 std: 1.0000231350275914
# floors => mean: 8.416181943949737e-17 std: 1.0000231350275914
# waterfront => mean: -5.2601137149685855e-18 std: 1.0000231350275919
# view => mean: -1.0520227429937171e-17 std: 1.0000231350275917
# condition => mean: -2.5774557203346067e-16 std: 1.0000231350275917
# grade => mean: 1.7884386630893189e-16 std: 1.0000231350275914
# sqft_above => mean: 1.1046238801434028e-16 std: 1.0000231350275917
# ...

# %% [markdown]
# ## q4

# %% [markdown]
# In order to handle categorial data and converting them to numerical values there are numerous ways.
# Generally two methods are used for handling them :
# * One Hot Encoding :
# In this method new columns will be added for each categorial value and a binary vector will be assigned to each row.
# * Label encoding :
# A number will be assigned to each categorial value (ususally usefull when dealling with data that has numerous categories).
#
# Generally this operation must be done for features which will be effective in prediction.
#
# Label encodeing is not a good option here since there is no particular ordering in our categories(categorial values).
# It's better to use One Hot Encoding here, we'll use ordinal encoding for 'date'column since it has lots of different values(categories).
# However since there are not so many different values in 'location' and 'style' features, we'll use One Hot Encoding for them. (In such case not so many columns would be added and not so much memory would be spent either).
# columns like 'unnamed 0.1, unnamed 0.2, unnamed(first 3 columns) are useless here (we'll talk about them in next question)

# %%
from sklearn.preprocessing import OrdinalEncoder

ordinal = OrdinalEncoder()
ordinal_features = ['date']
house_data[ordinal_features] = ordinal.fit_transform(house_data[ordinal_features].astype(str)).astype(int)

# %%
house_data = pd.get_dummies(house_data, columns = ['style', 'location'])

# %%
house_data.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        id  date     price  bedrooms  \
# 0     -1.731971     -1.731971   -1.731971  0.886146   164  221900.0 -0.389673
# 1     -1.731810     -1.731810   -1.731810  0.637511   220  538000.0 -0.389673
# 2     -1.731650     -1.731650   -1.731650  0.365444   290  180000.0 -1.450111
# 3     -1.731490     -1.731490   -1.731490 -0.727656   220  604000.0  0.670765
# 4     -1.731330     -1.731330   -1.731330 -0.912881   283  510000.0 -0.389673
#
#    bathrooms  sqft_living  sqft_lot  ...  sqft_lot15  house_age  \
# 0  -1.424274    -1.016219 -0.228321  ...   -0.260715   0.544898
# 1   0.176897     0.557526 -0.189885  ...   -0.187868   0.681079
# 2  -1.424274    -1.480417 -0.123298  ...   -0.172375   1.293892
# 3   1.137599    -0.133111 -0.244014  ...   -0.284522   0.204446
# 4  -0.143337    -0.450124 -0.169653  ...   -0.192849  -0.544548
#
#    style_Cape Cod  style_Colonial  style_Contemporary  style_Ranch  \
# ...

# %% [markdown]
# ## q5

# %% [markdown]
# If a column(feature) does not contain values important and effective for prediction, or has lots of missing values (nan) inside it, we can drop it.
# Generally features that has a very low 'information gain' can be deleted/removed from our dataset.
# It must be noted that if we do not remove these features from our dataset we might face overfitting problems in our prediction procedure.
# Now let us check our dataset once again.
# We use sklearn library to check information gain of features in our dataset.

# %%
from sklearn.feature_selection import mutual_info_classif

x=house_data.drop(['price'], axis=1, inplace=False)
y=house_data['price']
info = mutual_info_classif(x, y)
ig = pd.Series(info)
ig.index = x.columns
ig.sort_values(ascending = False, inplace = True)

plt.title('Mutual information with respect to features')
ig.plot.bar(figsize=(25,20))
plt.show()

# %% [markdown]
# If we take a look at the first three columns(features) of our dataset, we realize that there are identical to each other and the distribution of values inside them, actually make these features act as a kind of id whch can't be generalized well.
# We mark these column to be deleted to reduce probability of overfitting.
# Also as we can see from generated plot at top the 'date' feature also does not have much information gain, so we can also delete this column.
# other columns ???
# id ???

# %%
house_data.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        id  date     price  bedrooms  \
# 0     -1.731971     -1.731971   -1.731971  0.886146   164  221900.0 -0.389673
# 1     -1.731810     -1.731810   -1.731810  0.637511   220  538000.0 -0.389673
# 2     -1.731650     -1.731650   -1.731650  0.365444   290  180000.0 -1.450111
# 3     -1.731490     -1.731490   -1.731490 -0.727656   220  604000.0  0.670765
# 4     -1.731330     -1.731330   -1.731330 -0.912881   283  510000.0 -0.389673
#
#    bathrooms  sqft_living  sqft_lot  ...  sqft_lot15  house_age  \
# 0  -1.424274    -1.016219 -0.228321  ...   -0.260715   0.544898
# 1   0.176897     0.557526 -0.189885  ...   -0.187868   0.681079
# 2  -1.424274    -1.480417 -0.123298  ...   -0.172375   1.293892
# 3   1.137599    -0.133111 -0.244014  ...   -0.284522   0.204446
# 4  -0.143337    -0.450124 -0.169653  ...   -0.192849  -0.544548
#
#    style_Cape Cod  style_Colonial  style_Contemporary  style_Ranch  \
# ...

# %%
house_data.drop(['Unnamed: 0.2','Unnamed: 0.1','Unnamed: 0','date'], axis=1, inplace=True)
#see if 'date' is also good for deletion

# %%
house_data.head()
# Out:
#          id     price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# 0  0.886146  221900.0 -0.389673  -1.424274    -1.016219 -0.228321 -0.988457
# 1  0.637511  538000.0 -0.389673   0.176897     0.557526 -0.189885  0.000000
# 2  0.365444  180000.0 -1.450111  -1.424274    -1.480417 -0.123298 -0.988457
# 3 -0.727656  604000.0  0.670765   1.137599    -0.133111 -0.244014 -0.988457
# 4 -0.912881  510000.0 -0.389673  -0.143337    -0.450124 -0.169653 -0.988457
#
#    waterfront      view  condition  ...  sqft_lot15  house_age  \
# 0   -0.087173 -0.305759  -0.629187  ...   -0.260715   0.544898
# 1   -0.087173 -0.305759  -0.629187  ...   -0.187868   0.681079
# 2   -0.087173 -0.305759  -0.629187  ...   -0.172375   1.293892
# 3   -0.087173 -0.305759   2.444294  ...   -0.284522   0.204446
# 4   -0.087173 -0.305759  -0.629187  ...   -0.192849  -0.544548
#
#    style_Cape Cod  style_Colonial  style_Contemporary  style_Ranch  \
# ...

# %% [markdown]
# ## q6

# %% [markdown]
# One of the common ways of splitting data to test/train sets is to take first X% of data for train and the rest for the test set.
# However it must be noted that the dataset must actually be shuffled before splliting and the ratio of unique 'price' values to all data in both test and train must be equal(or very close).
# The ratio of each output(reault of prediction which is price here) in test and train must be equal too, and our train model must not face a bias in prediction and must not tend to a specific value (output).
# Our test set on the other hand should also have a good prediction.
# In order to split test/train like said we can use 'train_test_split' in 'Sklearn' library.
# Usually a 70/30 or 80/20 ratio for train/test split is good. (we use 75/25 here)

# %%
from sklearn.model_selection import train_test_split
data_val, price_label = house_data.drop(['price'], axis=1, inplace=False) , house_data['price']
data_train, data_test, label_train, label_test = train_test_split(data_val, price_label, random_state=42, test_size=0.25) #the answer to the ultimate question of life, the universe, and everything. :))
print(len(data_test),  len(data_train))
print(len(label_test), len(label_train))
# Out:
# 5404 16209
# 5404 16209

# %% [markdown]
# ## q7

# %% [markdown]
# This set is usually used for setting hyper parameters.
# Actually, before evaluating and running the model on the test data, we adjust the hyper parameters of our model using validation data.

# %% [markdown]
# # Phase 1

# %% [markdown]
# # Linear Regression

# %% [markdown]
# Main form of simple linear regression function:
# $$f(x) = \alpha x + \beta$$
#
# here we want to find the intercept($\alpha$) and slope($\beta$) by minimizing the derivation of the RSS function:
#
# - step 1: Compute RSS of the training data
#
# $$ RSS = \Sigma (y_i - (\hat{\beta} + \hat{\alpha} * x_i) )^2 $$
#
# - step 2: Compute the derivatives of the RSS function in term of $\underline{\alpha}$ and $\underline{\beta}$, and set them equal to 0 to find the desired parameters
#
# $$ \frac{\partial RSS}{\partial \beta} = \Sigma (-f(x_i) + \hat{\beta} + \hat{\alpha} * x_i) = 0$$
# $$ \to \hat{\beta} = \hat{y} - \hat{\alpha} \hat{x} \to (1)$$
#
#
# $$ \frac{\partial RSS}{\partial \alpha} = \Sigma (-2 x_i y_i + 2 \hat{\beta} x_i + 2\hat{\alpha} x_i ^ 2) = 0 \to (2)$$
#
# $$ (1) , (2) \to \hat{\alpha} = \frac{\Sigma{(x_i - \hat{x})(y_i - \hat{y})}}{\Sigma{(x_i - \hat{x})^2}}
# $$
# $$ \hat{\beta} = \hat{y} - \hat{\alpha} \hat{x}$$

# %% [markdown]
# Based on the formula above, complete this function to compute the parameters of a simple linear regression

# %%
def simple_linear_regression(input_feature, output):
    # TO DO:
    
    # compute the sum of input_feature and output
    sum_input = input_feature.sum()
    sum_output = output.sum()
    num_data = len(output)
        
    # compute the product of the output and the input_feature and its sum
    product_of_inp_out = input_feature * output
    sum_product = product_of_inp_out.sum()
    
    # compute the squared value of the input_feature and its sum
    input_squared = input_feature*input_feature
    squared_sum  = input_squared.sum()
    
    # use the formula for the slope
    numerator = sum_product - ((float(1)/num_data) * (sum_input*sum_output))
    denominator = squared_sum - ((float(1)/num_data) * (sum_input*sum_input))
    slope = numerator/denominator
    
    # use the formula for the intercept
    intercept = output.mean()-(slope*input_feature.mean())

    return (intercept, slope)

# %% [markdown]
# Now complete this function to predict the value of given data based on the calculated intercept and slope

# %%
def get_regression_predictions(input_feature, intercept, slope):
    # TO DO:
    # calculate the predicted values:
    predicted_values= slope*input_feature + intercept
    return (predicted_values)

# %% [markdown]
# Now that we have a model and can make predictions let's evaluate our model using Root Mean Square Error (RSME). RMSE is the square root of the mean of the squared differences between the residuals and the residuals is just a fancy word for the difference between the predicted output and the true output.
#
# Complete the following function to compute the RSME of a simple linear regression model given the input_feature, output, intercept and slope:

# %%
def get_root_mean_square_error(predicted_values , output):
    # TO DO:

    # Compute the residuals (since we are squaring it doesn't matter which order you subtract)
    residual = output - (predicted_values)

    # square the residuals and add them up
    RSS = residual * residual
#     print(RSS.sum)
    # find the mean of the above phrase
    mean = RSS.sum()/len(RSS)
    # calculate the root
    RMSE = math.sqrt(mean)
    return(RMSE)

# %% [markdown]
# AS you might guessed, the RMSE has no bound and it is not easy to find out the percentage of fitting the model into data with it. instead, we use R2 score. The R2 score is calculated by comparing the sum of the squared differences between the actual and predicted values of the dependent variable to the total sum of squared differences between the actual and mean values of the dependent variable. Matematically, the R2 score formula is shown as follows:
#
# $$R^2 = 1 - \frac{SSres}{SStot} = 1 - \frac{\sum_{i=1}^{n} (y_{i,true} - y_{i,pred})^2}{\sum_{i=1}^{n} (y_{i,true} - \bar{y}_{true})^2} $$

# %% [markdown]
# In this step, complete the following function to calculate the R2 score of a given input_feature, output, intercept, and slope:

# %%
def get_r2_score(predicted_values, output):
    # TO DO:

    # then compute the residuals (since we are squaring it doesn't matter which order you subtract)
    residual = output - (predicted_values)
    
    # square the residuals and add them up -> SSres
    SSres = residual * residual
    SSres = SSres.sum()
    
    # compute the SStot
    err_mean = sum(output)/len(output)
    err = output
    err = np.array([x - err_mean for x in err])
    
    SStotL= err * err
    SStot = SStotL.sum()
    
    # compute the R2 score value
    R2_score = 1-(SSres/SStot)
    return(R2_score)

# %% [markdown]
# Now calculate the fitness of the model and explain the outputs

# %%
# TO DO:
## test for train data
designated_feature_list = ['sqft_living' , 'yr_built' , 'grade' , 'zipcode']

for feature in designated_feature_list:
    print('*** Feature:', feature)
    intercept, slope = simple_linear_regression(regr_data_ph1[feature], regr_data_ph1['price'])
    predicted        = get_regression_predictions(regr_data_ph1[feature], intercept, slope)
    RSME             = get_root_mean_square_error(predicted, regr_data_ph1['price'])
    R2               = get_r2_score(predicted, regr_data_ph1['price'])
    print("RSME:", RSME)
    print("R2 Score:", R2)
    print(' ')
# Out:
# *** Feature: sqft_living
# RSME: 285321.0718932141
# R2 Score: 0.3967479881303173
#
# *** Feature: yr_built
# RSME: 366890.6155823228
# R2 Score: 0.002519780978244235
#
# *** Feature: grade
# RSME: 338384.9116288185
# R2 Score: 0.15149761982248722
#
# *** Feature: zipcode
# RSME: 366834.13721633365
# R2 Score: 0.0028268573348362303

# %% [markdown]
# By analyzing values we understand that .......

# %% [markdown]
# # Phase 2
#
# # classification

# %% [markdown]
# ## price level
#
# Before implementing classification we must create 'price_level' feature in our data set.
# This will be done for both test and train datasets.

# %%
import copy
train_label_median = label_train.median()
test_label_median = label_test.median()
print(train_label_median, test_label_median)

print(len(label_train))
label_train_lv = copy.deepcopy(label_train)
label_test_lv  = copy.deepcopy(label_test)

for i, v in label_train.items() :
    if(v > train_label_median):
        label_train_lv[i] = "HIGH"
    else:
        label_train_lv[i] = "LOW"

for i, v in label_test.items() :
    if(v > test_label_median):
        label_test_lv[i] = "HIGH"
    else:
        label_test_lv[i] = "LOW"
        
print(label_train_lv)
print(label_train)
print(label_test_lv)
print(label_test)
# Out:
# 450000.0 450650.0
# 16209
# 5945      LOW
# 8423      LOW
# 13488     LOW
# 20731     LOW
# 2358      LOW
#          ...
# 11964     LOW
# 21575     LOW
# 5390     HIGH
# 860       LOW
# 15795     LOW
# Name: price, Length: 16209, dtype: object
# 5945     268643.0
# 8423     245000.0
# 13488    200000.0
# 20731    352499.0
# 2358     232000.0
#            ...
# 11964    378000.0
# 21575    399950.0
# 5390     575000.0
# 860      245000.0
# 15795    315000.0
# Name: price, Length: 16209, dtype: float64
# 735       LOW
# 2830     HIGH
# 4106     HIGH
# 16218    HIGH
# 19964    HIGH
#          ...
# 11144    HIGH
# 17803    HIGH
# 268       LOW
# 518      HIGH
# 8482      LOW
# Name: price, Length: 5404, dtype: object
# 735       365000.0
# 2830      865000.0
# 4106     1040000.0
# 16218    1490000.0
# 19964     711000.0
#            ...
# 11144     650000.0
# 17803     705000.0
# 268       272500.0
# 518      2250000.0
# 8482      330000.0
# Name: price, Length: 5404, dtype: float64

# %% [markdown]
# ## q1 , q2
# After the execution of each algorithm, the confusion matrix is drawn and the necessary calculations are also displayed. In some algorithms, in addition to manually testing the model with different parameter values, the GridSearchCV function has also been used.

# %% [markdown]
# ## q3
# ### Underfitting
#
# Undefitting happens when we have not trained our model well for reasons such as bad hyperparameter values or low train data.
# If this happens, our model has little accuracy and cannot make good predictions.
# In other words, underfitting happenes when our model does not even predict the training data correctly, which in this, our model
# is high bias.
#
# ### Overfitting
# Overfitting happens if we pay too much attention to details and even model the noise in the data.
# In this case, the accuracy of the model is very high for predicting the train data, but it is low for the test data.
# In fact, there is a gap between the accuracy of the training and the test data, which in this our models are high variance.

# %% [markdown]
# ## q4
# In the models implemented below, this(overfitting/underfitting) may happen due to the different values of the parameters and the way the data is divided(splitted).
# For each algorithm, the graph and various accuracy measurements are displayed, and for each algorithm, calculations have been made separately, which can be seen below.
# We try to reduce the possibility of overfitting by removing the columns that have very low information gain and changing the various parameters of the model as well as the pre-processing that we did in the previous steps.

# %% [markdown]
# # ‫‪K-Nearest-Neighbours‬‬

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

def plot_KNN_model(neighbour_range_max) : 
    neighbours = range(1,neighbour_range_max)
    test_accuracy  = []
    train_accuracy = []
    
    for i in neighbours:
        knn = KNeighborsClassifier(n_neighbors=i)
        knn.fit(data_train, label_train_lv)
        
        train_prediction = knn.predict(data_train)
        train_accuracy.append(accuracy_score(label_train_lv, train_prediction))
        
        test_prediction = knn.predict(data_test)
        test_accuracy.append(accuracy_score(label_test_lv, test_prediction))
    
    plt.figure(figsize=(5, 5))
    plt.plot(neighbours, train_accuracy, label='Train')
    plt.plot(neighbours, test_accuracy,  label='Test')
    plt.legend()
    plt.xlabel("neighbours number")
    plt.title('N_neighbors accuracy stataus')
    plt.show()

plot_KNN_model(20)
plot_KNN_model(50)

# %% [markdown]
# By looking at the plot we can see that the difference between accuracy in train and test for low neighbours (e.g, 1) is very high (high accuracy in train and low one in test).
# This indicates overfitting, however if we look at plot again values between 15 to 20 would be much better for K in knn, so we set as a value in this range (18 here)
# Note that a value between 20 to 30 would be also good here, but we choose 18 here.

# %%
knn = KNeighborsClassifier(n_neighbors=i)
knn.fit(data_train, label_train_lv)

train_prediction = knn.predict(data_train)
train_accuracy.append(accuracy_score(label_train_lv, train_prediction))

test_prediction = knn.predict(data_test)
test_accuracy.append(accuracy_score(label_test_lv, test_prediction))

cnf_matrix = confusion_matrix(label_test_lv, test_prediction, labels=knn.classes_)
display = ConfusionMatrixDisplay(confusion_matrix=cnf_matrix, display_labels=knn.classes_)
display.plot()
plt.show()

cnf_matrix_2 = confusion_matrix(label_train_lv, train_prediction, labels=knn.classes_)
display = ConfusionMatrixDisplay(confusion_matrix=cnf_matrix_2, display_labels=knn.classes_)
display.plot()
plt.show()

# %% [markdown]
# Accoring to the follwing formulas we can calculate accuracy, precision and recall score for the recent prediction :
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# for train :
# accuracy  =  ( 7016+7114 / 7016+7114+1030+1049 ) = 14130 / 16209 = 87%
# precision =  ( 7114 / 7114+1030 ) = 7114/8144  = 87%
# recall    =  ( 7714 / 7114+1049 ) = 87%
#
# for test:
# accuracy  =  ( 2355+2324 / 2355+2324+378+347 ) = 4769 / 5404 = 86.5%
# precision =  ( 2355 / 2355+378 ) = 2355/2733  = 86%
# recall    =  ( 2355 / 2355+347 ) = 87%
#
# now we'll calculate them in code too:

# %%
from sklearn.metrics import recall_score, precision_score
accuracy_test  = accuracy_score(label_test_lv, test_prediction)
precision_test = precision_score(label_test_lv, test_prediction, pos_label='LOW')
recall_test    = recall_score(label_test_lv, test_prediction, pos_label='LOW')

accuracy_train  =  accuracy_score(label_train_lv, train_prediction)
precision_train =  precision_score(label_train_lv, train_prediction, pos_label='LOW')
recall_train    =  recall_score(label_train_lv, train_prediction, pos_label='LOW')
print('for training data : ')
print('accuracy:', accuracy_train, 'precision:', precision_train, 'recall:', recall_train)
print('for testing data : ')
print('accuracy:', accuracy_test, 'precision:', precision_test, 'recall:', recall_test)
# Out:
# for training data :
# accuracy: 0.8717379233759023 precision: 0.8735265225933202 recall: 0.8714933235330148
# for testing data :
# accuracy: 0.865840118430792 precision: 0.8616904500548848 recall: 0.8715766099185789

# %% [markdown]
# Now the prediction scores the train/test data are close to each other.

# %% [markdown]
# # Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier

def plot_decision_tree_model(depth_range_max) :
    depths = range(1, depth_range_max)
    test_accuracy  = []
    train_accuracy = []
    
    for depth in depths:
        decision_tree = DecisionTreeClassifier(max_depth=depth)
        decision_tree.fit(data_train, label_train_lv)
    
        train_prediction = decision_tree.predict(data_train)
        train_accuracy.append(accuracy_score(label_train_lv, train_prediction))
    
        test_prediction = decision_tree.predict(data_test)
        test_accuracy.append(accuracy_score(label_test_lv, test_prediction))
    
    plt.figure(figsize=(5, 5))
    plt.plot(depths, train_accuracy, label='Train')
    plt.plot(depths, test_accuracy, label='Test')
    plt.legend()
    plt.xlabel('depth')
    plt.title('Decision Tree Accuracy status')
    plt.show()
    
plot_decision_tree_model(30)
plot_decision_tree_model(60)

# %% [markdown]
# As we can see, if our max_depth goes more than 5 we'll face overfitting, so in order to avoid it and also to avoid underfitting, we'll set our max_depth to 5.
# Now lets check other factors in the classifier and analyze them.

# %%
decision_tree = DecisionTreeClassifier(max_depth=5)
decision_tree.fit(data_train, label_train_lv)

train_prediction = decision_tree.predict(data_train)
train_accuracy.append(accuracy_score(label_train_lv, train_prediction))

test_prediction = decision_tree.predict(data_test)
test_accuracy.append(accuracy_score(label_test_lv, test_prediction))

cnf_matrix_3 = confusion_matrix(label_test_lv, test_prediction, labels=decision_tree.classes_)
display = ConfusionMatrixDisplay(confusion_matrix=cnf_matrix_3, display_labels=decision_tree.classes_)
display.plot()
plt.show()

cnf_matrix_4 = confusion_matrix(label_train_lv, train_prediction, labels=decision_tree.classes_)
display = ConfusionMatrixDisplay(confusion_matrix=cnf_matrix_4, display_labels=decision_tree.classes_)
display.plot()
plt.show()

# %%
accuracy_test   =  accuracy_score(label_test_lv, test_prediction)
precision_test  =  precision_score(label_test_lv, test_prediction, pos_label='LOW')
recall_test     =  recall_score(label_test_lv, test_prediction, pos_label='LOW')

accuracy_train  =  accuracy_score(label_train_lv, train_prediction)
precision_train =  precision_score(label_train_lv, train_prediction, pos_label='LOW')
recall_train    =  recall_score(label_train_lv, train_prediction, pos_label='LOW')
print('for training data : ')
print('accuracy:', accuracy_train, 'precision:', precision_train, 'recall:', recall_train)
print('for testing data : ')
print('accuracy:', accuracy_test, 'precision:', precision_test, 'recall:', recall_test)
# Out:
# for training data :
# accuracy: 0.8671108643346289 precision: 0.8572957545486978 recall: 0.8831312017640573
# for testing data :
# accuracy: 0.8730569948186528 precision: 0.8561837455830389 recall: 0.8967431532198371

# %% [markdown]
# ## min_samples_leaf
# We now set values for 'min_samples_leaf' attribute in decision tree classifier.

# %%
def plot_decision_tree_model_min_leaf(depth_range_max) :
    leaves = range(1, depth_range_max)
    test_accuracy  = []
    train_accuracy = []
    
    for leaf in leaves:
        decision_tree = DecisionTreeClassifier(max_depth=5, min_samples_leaf=leaf)
        decision_tree.fit(data_train, label_train_lv)
    
        train_prediction = decision_tree.predict(data_train)
        train_accuracy.append(accuracy_score(label_train_lv, train_prediction))
    
        test_prediction = decision_tree.predict(data_test)
        test_accuracy.append(accuracy_score(label_test_lv, test_prediction))
    
    plt.figure(figsize=(5, 5))
    plt.plot(leaves, train_accuracy, label='Train')
    plt.plot(leaves, test_accuracy, label='Test')
    plt.legend()
    plt.xlabel('leaf')
    plt.title('Decision Tree Accuracy status with M_S_L') #M_S_L => mean_sample_leaf
    plt.show()
    
plot_decision_tree_model_min_leaf(50)    
plot_decision_tree_model_min_leaf(300)

# %% [markdown]
# In order to avoid underfitting/overfitting we set mean_samples_leaf to 20 (between 10 to 30 is ok in this case).
# The more we increase min_samples_leaf the less accuracy we get!
# Now lets check the score measurements.

# %%
decision_tree = DecisionTreeClassifier(max_depth=5, min_samples_leaf=20)
decision_tree.fit(data_train, label_train_lv)

train_prediction = decision_tree.predict(data_train)
train_accuracy.append(accuracy_score(label_train_lv, train_prediction))

test_prediction = decision_tree.predict(data_test)
test_accuracy.append(accuracy_score(label_test_lv, test_prediction))

cnf_matrix_5 = confusion_matrix(label_test_lv, test_prediction, labels=decision_tree.classes_)
display = ConfusionMatrixDisplay(confusion_matrix=cnf_matrix_5, display_labels=decision_tree.classes_)
display.plot()
plt.show()

cnf_matrix_6 = confusion_matrix(label_train_lv, train_prediction, labels=decision_tree.classes_)
display = ConfusionMatrixDisplay(confusion_matrix=cnf_matrix_6, display_labels=decision_tree.classes_)
display.plot()
plt.show()

# %%
accuracy_test   =  accuracy_score(label_test_lv, test_prediction)
precision_test  =  precision_score(label_test_lv, test_prediction, pos_label='LOW')
recall_test     =  recall_score(label_test_lv, test_prediction, pos_label='LOW')

accuracy_train  =  accuracy_score(label_train_lv, train_prediction)
precision_train =  precision_score(label_train_lv, train_prediction, pos_label='LOW')
recall_train    =  recall_score(label_train_lv, train_prediction, pos_label='LOW')
print('for training data : ')
print('accuracy:', accuracy_train, 'precision:', precision_train, 'recall:', recall_train)
print('for testing data : ')
print('accuracy:', accuracy_test, 'precision:', precision_test, 'recall:', recall_test)
# Out:
# for training data :
# accuracy: 0.8670491702140786 precision: 0.8562618595825426 recall: 0.8844787455592307
# for testing data :
# accuracy: 0.8730569948186528 precision: 0.8541813070976809 recall: 0.8997039230199851

# %% [markdown]
# Lets use gridSearchCV to find optimal value of model paramters.
#
# ## GridSearchCV

# %%
parameter_grid_tree = {
              'max_depth': [1, 2, 3, 4, 5, 10, 17, 18, 20, 22, 24, 26],
              'min_samples_split': [2, 3, 4],
              'min_samples_leaf': [10, 20, 24, 25, 26, 38, 39, 40, 41, 42, 100, 150, 240, 280, 1000]
             }
GSCV_tree = GridSearchCV(decision_tree, parameter_grid_tree,n_jobs = -1, verbose = 0, scoring = 'accuracy', cv = 5)
GSCV_tree.fit(data_train, label_train_lv)

print(GSCV_tree.best_params_)
print(GSCV_tree.score(data_train, label_train_lv))
print(GSCV_tree.score(data_test , label_test_lv))
# Out:
# {'max_depth': 20, 'min_samples_leaf': 20, 'min_samples_split': 4}
# 0.9109753840459004
# 0.8900814211695041

# %% [markdown]
# The above result shows the max accuracy we can get by changing hyperparameters and the value of those hyperparameters

# %% [markdown]
# # ‫‪‫‪Logistic‬‬ ‫‪Regression‬‬

# %%
from sklearn.linear_model import LogisticRegression

def plot_logistic_regression_model(iters_range_max) :
    iters = range(1, iters_range_max)
    test_accuracy  = []
    train_accuracy = []
    
    for i in iters:
        log_regression = LogisticRegression(max_iter=i, random_state=4)
        log_regression.fit(data_train, label_train_lv)
    
        train_prediction = log_regression.predict(data_train)
        train_accuracy.append(accuracy_score(label_train_lv, train_prediction))
    
        test_prediction = log_regression.predict(data_test)
        test_accuracy.append(accuracy_score(label_test_lv, test_prediction))
    
    plt.figure(figsize=(5, 5))
    plt.plot(iters, train_accuracy, label='Train')
    plt.plot(iters, test_accuracy,  label='Test')
    plt.legend()
    plt.xlabel('max_iter')
    plt.title('Logistic regression Accuracy status') #M_S_L => mean_sample_leaf
    plt.show()

plot_logistic_regression_model(50)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\lenovo\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# The accuracies of test/train sets are close to each other and it can be said that there is almost no overfitting in most values ranges.
# Now in order to find optimal value of parameters we use searchGridCV.
# But before this we calculate evaluation scores considering max_iter=30

# %%
log_regression = LogisticRegression(max_iter=30, random_state=4)
log_regression.fit(data_train, label_train_lv)

train_prediction = log_regression.predict(data_train)
train_accuracy.append(accuracy_score(label_train_lv, train_prediction))

test_prediction = log_regression.predict(data_test)
test_accuracy.append(accuracy_score(label_test_lv, test_prediction))

cnf_matrix_7 = confusion_matrix(label_test_lv, test_prediction, labels=log_regression.classes_)
display = ConfusionMatrixDisplay(confusion_matrix=cnf_matrix_7, display_labels=log_regression.classes_)
display.plot()
plt.show()

cnf_matrix_8 = confusion_matrix(label_train_lv, train_prediction, labels=log_regression.classes_)
display = ConfusionMatrixDisplay(confusion_matrix=cnf_matrix_8, display_labels=log_regression.classes_)
display.plot()
plt.show()

# %%
accuracy_test   =  accuracy_score(label_test_lv, test_prediction)
precision_test  =  precision_score(label_test_lv, test_prediction, pos_label='LOW')
recall_test     =  recall_score(label_test_lv, test_prediction, pos_label='LOW')

accuracy_train  =  accuracy_score(label_train_lv, train_prediction)
precision_train =  precision_score(label_train_lv, train_prediction, pos_label='LOW')
recall_train    =  recall_score(label_train_lv, train_prediction, pos_label='LOW')

print('for training data : ')
print('accuracy:', accuracy_train, 'precision:', precision_train, 'recall:', recall_train)
print('for testing data : ')
print('accuracy:', accuracy_test, 'precision:', precision_test, 'recall:', recall_test)
# Out:
# for training data :
# accuracy: 0.8353383922512184 precision: 0.8328889966068832 recall: 0.8419698640205807
# for testing data :
# accuracy: 0.8486306439674315 precision: 0.8373925501432665 recall: 0.8652849740932642

# %% [markdown]
# ### searchGridCV

# %%
param_grid = {'penalty':('l1','l2', "elasticnet"), #Specify the norm of the penalty:
             'tol':(0.0001, 0.00001, 0.00005), #Tolerance for stopping criteria default= 1e-4
             'C':(0.01, 0.1, 0.5, 1, 1.3, 1.5, 1.8, 2, 3), #Inverse of regularization strength; smaller values specify stronger regularization.
#              'solver':("lbfgs", "liblinear", "newton-cg", "newton-cholesky", "sag", "saga"), #takes so much time !
              'max_iter':(5, 10, 30, 50, 100, 150, 200, 250)
             }
log_classifier = LogisticRegression()
gs_log_reg = GridSearchCV(log_classifier, param_grid,n_jobs = -1, verbose = 0, scoring = 'accuracy', cv = 5)
gs_log_reg.fit(data_train, label_train_lv)
print(gs_log_reg.best_params_)
print(gs_log_reg.score(data_train, label_train_lv))
print(gs_log_reg.score(data_test, label_test_lv))
# Out:
# c:\users\lenovo\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 2160 fits failed out of a total of 3240.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1080 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\users\lenovo\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\users\lenovo\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
# ...

# %% [markdown]
# # Ensemble Learning

# %% [markdown]
# ## q1
#
# * max_depth :
# Specifies the maximum height of each tree in the forest.
#
# * n_estimators :
# Specifies the number of trees in the forest.
#
# * leaf_samples_min :
# Specifies the minimum amount of spliting. For example, if the value of this variable is equal to 10, when the splitting of a vertex reaches less than 10, the work will continue.
#
# * verbose :
# Controls the verbosity when fitting and predicting. (default=0)
#
# * max_features: {“sqrt”, “log2”, None}, int or float, default=”sqrt”
# The number of features to consider when looking for the best split
#
# * bootstrapbool, default=True
# Whether bootstrap samples are used when building trees. If False, the whole dataset is used to build each tree.
#
# We will see the effects of changing these hyperparameters in the coming sections.

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from mlxtend.evaluate import bias_variance_decomp

def plot_random_forest_model(depth_range_max):
    depths = range(1, depth_range_max)
    
    test_accuracy  = []
    train_accuracy = []
    
    for depth in depths:
        forest = RandomForestClassifier(max_depth=depth)
        forest.fit(data_train, label_train_lv)
    
        train_prediction = forest.predict(data_train)
        train_accuracy.append(accuracy_score(label_train_lv, train_prediction))
    
        test_prediction = forest.predict(data_test)
        test_accuracy.append(accuracy_score(label_test_lv, test_prediction))
    
    plt.figure(figsize=(5, 5))
    plt.plot(depths, train_accuracy, label='Train')
    plt.plot(depths, test_accuracy, label='Test')
    plt.xlabel('max_depth')
    plt.legend()
    plt.title('Random Forest Accuracy Status')
    plt.show()

plot_random_forest_model(30)

# %% [markdown]
# In order to avoid overfitting/underfitting, max_depth=11 is choosen.
# now lets check other parameters but before that lets compute variance and bias.

# %%
# forest = RandomForestClassifier(max_depth=11)
# forest.fit(data_train, label_train_lv)
# label_test_decomp = copy.deepcopy(label_test_lv)
# label_train_decomp = copy.deepcopy(label_train_lv)

# for i, v in label_train_lv.items() :
#     if(v == "HIGH"):
#         label_train_decomp[i] = 1
#     else:
#         label_train_decomp[i] = 0

# for i, v in label_test_lv.items() :
#     if(v == "HIGH"):
#         label_test_decomp[i] = 1
#     else:
#         label_test_decomp[i] = 0
        
# mse, bias, variance = bias_variance_decomp(forest, data_train.values, label_train_decomp.values, 
#                                       data_test.values, label_test_decomp.values, loss='mse', num_rounds=100)

# print(f"Bias is : {bias}\nVariance is : {variance}")

# %%
forest = RandomForestClassifier(max_depth=11)
forest.fit(data_train, label_train_lv)

train_prediction = forest.predict(data_train)
train_accuracy.append(accuracy_score(label_train_lv, train_prediction))

test_prediction = forest.predict(data_test)
test_accuracy.append(accuracy_score(label_test_lv, test_prediction))

accuracy_test   =  accuracy_score(label_test_lv, test_prediction)
precision_test  =  precision_score(label_test_lv, test_prediction, pos_label='LOW')
recall_test     =  recall_score(label_test_lv, test_prediction, pos_label='LOW')

accuracy_train  =  accuracy_score(label_train_lv, train_prediction)
precision_train =  precision_score(label_train_lv, train_prediction, pos_label='LOW')
recall_train    =  recall_score(label_train_lv, train_prediction, pos_label='LOW')

print('for training data : ')
print('accuracy:', accuracy_train, 'precision:', precision_train, 'recall:', recall_train)
print('for testing data : ')
print('accuracy:', accuracy_test, 'precision:', precision_test, 'recall:', recall_test)
# Out:
# for training data :
# accuracy: 0.958233080387439 precision: 0.9609605911330049 recall: 0.9558985667034179
# for testing data :
# accuracy: 0.9133974833456698 precision: 0.9064774381368268 recall: 0.9219096965210954

# %%
def plot_random_forest_model_n_est(estimator_range_max):
    estimators = range(1, estimator_range_max)
    
    test_accuracy  = []
    train_accuracy = []
    
    for estimator in estimators:
        forest = RandomForestClassifier(max_depth=11, n_estimators=estimator)
        forest.fit(data_train, label_train_lv)
    
        train_prediction = forest.predict(data_train)
        train_accuracy.append(accuracy_score(label_train_lv, train_prediction))
    
        test_prediction = forest.predict(data_test)
        test_accuracy.append(accuracy_score(label_test_lv, test_prediction))
    
    plt.figure(figsize=(5, 5))
    plt.plot(estimators, train_accuracy, label='Train')
    plt.plot(estimators, test_accuracy, label='Test')
    plt.xlabel('n_estimators')
    plt.legend()
    plt.title('Random Forest Accuracy Status(max_depth=11)')
    plt.show()

plot_random_forest_model_n_est(30)

# %% [markdown]
# Choosing n_estimators=22 will help us avoid overfitting/underfitting.
# Now let's go for 'min_sample_leaf'

# %%
forest = RandomForestClassifier(max_depth=11, n_estimators=22)
forest.fit(data_train, label_train_lv)

train_prediction = forest.predict(data_train)
train_accuracy.append(accuracy_score(label_train_lv, train_prediction))

test_prediction = forest.predict(data_test)
test_accuracy.append(accuracy_score(label_test_lv, test_prediction))

accuracy_test   =  accuracy_score(label_test_lv, test_prediction)
precision_test  =  precision_score(label_test_lv, test_prediction, pos_label='LOW')
recall_test     =  recall_score(label_test_lv, test_prediction, pos_label='LOW')

accuracy_train  =  accuracy_score(label_train_lv, train_prediction)
precision_train =  precision_score(label_train_lv, train_prediction, pos_label='LOW')
recall_train    =  recall_score(label_train_lv, train_prediction, pos_label='LOW')

print('for training data : ')
print('accuracy:', accuracy_train, 'precision:', precision_train, 'recall:', recall_train)
print('for testing data : ')
print('accuracy:', accuracy_test, 'precision:', precision_test, 'recall:', recall_test)
# Out:
# for training data :
# accuracy: 0.9561971744092788 precision: 0.9602321847597876 recall: 0.9524684552247948
# for testing data :
# accuracy: 0.9071058475203553 precision: 0.9065040650406504 recall: 0.9078460399703923

# %%
def plot_random_forest_model_MSL(min_sample_leaf_range_max):
    leaves = range(1, min_sample_leaf_range_max)
    
    test_accuracy  = []
    train_accuracy = []
    
    for leaf in leaves:
        forest = RandomForestClassifier(max_depth=11, n_estimators=22, min_samples_leaf=leaf)
        forest.fit(data_train, label_train_lv)
    
        train_prediction = forest.predict(data_train)
        train_accuracy.append(accuracy_score(label_train_lv, train_prediction))
    
        test_prediction = forest.predict(data_test)
        test_accuracy.append(accuracy_score(label_test_lv, test_prediction))
    
    plt.figure(figsize=(5, 5))
    plt.plot(leaves, train_accuracy, label='Train')
    plt.plot(leaves, test_accuracy, label='Test')
    plt.xlabel('min_samples_leaf')
    plt.legend()
    plt.title('Random Forest Accuracy (max_depth=11, n_est=22)')
    plt.show()
    
plot_random_forest_model_MSL(30)

# %% [markdown]
# As we can see, increasing the value of min_samples_leaf increases the bias (decreasing the accuracy of the training data). Also, increasing this value to some extent causes the variance to decrease because the difference of accuracy between the training and test data decreases and then increases.

# %% [markdown]
# choosing min_samples_leaf=8 will help us avoid overfitting/underfitting

# %%
forest = RandomForestClassifier(max_depth=11, n_estimators=22, min_samples_leaf=8)
forest.fit(data_train, label_train_lv)

train_prediction = forest.predict(data_train)
train_accuracy.append(accuracy_score(label_train_lv, train_prediction))

test_prediction = forest.predict(data_test)
test_accuracy.append(accuracy_score(label_test_lv, test_prediction))

accuracy_test   =  accuracy_score(label_test_lv, test_prediction)
precision_test  =  precision_score(label_test_lv, test_prediction, pos_label='LOW')
recall_test     =  recall_score(label_test_lv, test_prediction, pos_label='LOW')

accuracy_train  =  accuracy_score(label_train_lv, train_prediction)
precision_train =  precision_score(label_train_lv, train_prediction, pos_label='LOW')
recall_train    =  recall_score(label_train_lv, train_prediction, pos_label='LOW')

print('for training data : ')
print('accuracy:', accuracy_train, 'precision:', precision_train, 'recall:', recall_train)
print('for testing data : ')
print('accuracy:', accuracy_test, 'precision:', precision_test, 'recall:', recall_test)
# Out:
# for training data :
# accuracy: 0.931087667345302 precision: 0.9339738851933974 recall: 0.9288251868185716
# for testing data :
# accuracy: 0.9096965210954848 precision: 0.9031318281136198 recall: 0.9178386380458919

# %% [markdown]
# ## q2
# As we know, bias is bias in favor or against a certain result. The less bias our model has, the more acceptable it is. In fact, bias is more related to the accuracy of the training data prediction, and the higher the accuracy of the training data, the lower the bias.
# Variance is more related to the difference between training and test data accuracy. If the difference between the accuracy of the training and test data is large, there is also (a large) variance.
# The relationship between variance and bias is inverse, that is, the higher the variance, the lower the bias and vice versa. According to these explanations, we are looking for a model that has a balance between these two variables and generally has less bias and variance.
# In general, both Decision Tree and Random Forest models are Low Bias and High Variance, but the variance of the Random Forest model is less than It is a decision tree model. Considering that the Random Forest model uses several trees for prediction, we expect a better result. In this model, the amount of variance is reduced, but the amount of bias may be increased bu generally saying it has served our interest in some parameters while not in other ones.
